# %%
import pandas as pd     #pd means any name , mine, yours

# %%
df=pd.read_excel(r'C:\Users\rekha\Desktop\iNeuron\Dress sales.xlsx')              #complete path where our file has stored

# %%
df
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel(r'C:\Users\rekha\Desktop\iNeuron\Dress sales.xlsx' , sheet_name = 'dress_ID')
#to read data from perticular data sheet
# Out:
#      Dress_ID  29/8/2013  31/8/2013
# 0  1006032852       2114       2274
# 1  1212192089        151        275
# 2  1190380701          6          7
# 3   966005983       1005       1128
# 4   876339541        996       1175

# %%
#by default 1st row is act as header

# %%
pd.read_excel(r'C:\Users\rekha\Desktop\iNeuron\Dress sales.xlsx' , sheet_name = 'Dress_ID 15')
# Out:
#     749031896  2498       2545       2627       2656
# 0  1055411544         22         28         40         43
# 1  1162628131          4          8         19         25
# 2   624314841       1587       1669       1729       1764
# 3   830467746         10         13         17         17
# 4   840857118          2          4         10         11
# 5  1113221101        122        143        243        279

# %%
pd.read_excel(r'C:\Users\rekha\Desktop\iNeuron\Attribute DataSet.xlsx')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
pd.read_excel(r'C:\Users\rekha\Downloads\Attribute DataSet.xlsx',sheet_name = 'ocean')  #sheet name is ocean in excel file
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# 4       Price     Rating       Size     Season
# 5         Low        4.6          M     Summer
# 6         Low          0          L     Summer
# 7        High          0          L     Automn
# 8     Average        4.6          L     Spring
# 9         Low        4.5          M     Summer
# 10        Low          0          M     Summer
# 11    Average          0         XL     Summer

# %%
pd.read_excel(r'C:\Users\rekha\Downloads\Attribute DataSet.xlsx', sheet_name = 'line',header=None, names=['A', 'B','C'])  
#1st row by default act as header so we have given the name as per our choice
# Out:
#            A     B       C
# Average  0.0  free  Automn
# Average  0.0  free  Spring
# Low      0.0  free  Summer
# Average  5.0  free  Summer
# Average  0.0  free  Spring
# Low      4.7     M  Winter
# Average  4.8     M  Summer

# %%
pd.read_excel(r'C:\Users\rekha\Downloads\Attribute DataSet.xlsx', sheet_name = 'sea_line')
# Out:
#      Material FabricType  Decoration
# 0         NaN    chiffon     ruffles
# 1  microfiber        NaN     ruffles
# 2    polyster        NaN         NaN
# 3        silk    chiffon  embroidary

# %%
pd.read_excel(r'C:\Users\rekha\Downloads\Attribute DataSet.xlsx', sheet_name = 'sea_line', header=None, names=['A', 'B', 'C'])
# Out:
#             A           B           C
# 0    Material  FabricType  Decoration
# 1         NaN     chiffon     ruffles
# 2  microfiber         NaN     ruffles
# 3    polyster         NaN         NaN
# 4        silk     chiffon  embroidary

# %%
df
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df.head()              #by default top 5 rows will display
# Out:
#      Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  2013-04-09 00:00:00  \
# 0  1006032852       2114       2274                 2491                 2660
# 1  1212192089        151        275                  570                  750
# 2  1190380701          6          7                    7                    7
# 3   966005983       1005       1128                 1326                 1455
# 4   876339541        996       1175                 1304                 1396
#
#    2013-06-09 00:00:00  2013-08-09 00:00:00  2013-10-09 00:00:00  \
# 0                 2727                 2887                 2930
# 1                  813                 1066                 1164
# 2                    8                    8                    9
# 3                 1507                 1621                 1637
# 4                 1432                 1559                 1570
#
#   2013-12-09 00:00:00 14/9/2013  ... 24/9/2013 26/9/2013 28/9/2013 30/9/2013  \
# ...

# %%
df.head(2)            #top 2 rows will display
# Out:
#      Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  2013-04-09 00:00:00  \
# 0  1006032852       2114       2274                 2491                 2660
# 1  1212192089        151        275                  570                  750
#
#    2013-06-09 00:00:00  2013-08-09 00:00:00  2013-10-09 00:00:00  \
# 0                 2727                 2887                 2930
# 1                  813                 1066                 1164
#
#   2013-12-09 00:00:00 14/9/2013  ... 24/9/2013 26/9/2013 28/9/2013 30/9/2013  \
# 0                3119      3204  ...      3554    3624.0      3706    3746.0
# 1                1558      1756  ...      2710    2942.0      3258    3354.0
#
#    2013-02-10 00:00:00  2013-04-10 00:00:00  2013-06-10 00:00:00  \
# 0               3795.0               3832.0                 3897
# 1               3475.0               3654.0                 3911
#
#    2010-08-10 00:00:00  2013-10-10 00:00:00  2013-12-10 00:00:00
# ...

# %%
df.tail()             #by default bottom 5 rows will display
# Out:
#       Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 495  713391965          0          0                    0
# 496  722565148          0          0                    0
# 497  532874347          0          0                    0
# 498  655464934          0          0                    0
# 499  919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 495                  560                  554                  544
# 496                  875                  866                  861
# 497                  734                  728                  726
# 498                  254                  259                  261
# 499                  538                  545                  558
#
#      2013-10-09 00:00:00 2013-12-09 00:00:00 14/9/2013  ... 24/9/2013  \
# 495                  537                 525       519  ...       400
# ...

# %%
df.tail(2)          #bottom 2 rows will display
# Out:
#       Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 498  655464934          0          0                    0
# 499  919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 498                  254                  259                  261
# 499                  538                  545                  558
#
#      2013-10-09 00:00:00 2013-12-09 00:00:00 14/9/2013  ... 24/9/2013  \
# 498                  263                 268       270  ...       257
# 499                  563                 578       585  ...       628
#
#     26/9/2013 28/9/2013 30/9/2013  2013-02-10 00:00:00  2013-04-10 00:00:00  \
# 498     256.0       255     254.0                253.0                250.0
# 499     632.0       639     645.0                651.0                655.0
#
#      2013-06-10 00:00:00  2010-08-10 00:00:00  2013-10-10 00:00:00  \
# 498                  249                249.0                249.0
# ...

# %%
pd.read_csv(r'C:\Users\rekha\Desktop\iNeuron\haberman.csv', header = None, names=['Age', "Patient's year", 'Number of positive', ' Survival status'])
# Out:
#      Age  Patient's year  Number of positive   Survival status
# 0     30              64                   1                 1
# 1     30              62                   3                 1
# 2     30              65                   0                 1
# 3     31              59                   2                 1
# 4     31              65                   4                 1
# ..   ...             ...                 ...               ...
# 301   75              62                   1                 1
# 302   76              67                   0                 1
# 303   77              65                   3                 1
# 304   78              65                   1                 2
# 305   83              58                   2                 2
#
# [306 rows x 4 columns]

# %%
pd.read_csv(r'C:\Users\rekha\Desktop\iNeuron\haberman1.csv')   #comma is replaced by *, not able to separete as given below
# Out:
#       30*64*1*1
# 0     30*62*3*1
# 1     30*65*0*1
# 2     31*59*2*1
# 3     31*65*4*1
# 4    33*58*10*1
# ..          ...
# 300   75*62*1*1
# 301   76*67*0*1
# 302   77*65*3*1
# 303   78*65*1*2
# 304   83*58*2*2
#
# [305 rows x 1 columns]

# %%
pd.read_csv(r'C:\Users\rekha\Desktop\iNeuron\haberman1.csv', sep='*')
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
pd.read_html(r'https://www.vedantu.com/maths/square-root-table-from-1-to-50', header = None)
# Out:
# [     0              1   2              3   4               5   6  \
#  0   No  SquareRoot(√)  No  SquareRoot(√)  No  Square Root(√)  No
#  1    1              1  11          3.317  21           4.583  31
#  2    2          1.414  12          3.464  22           4.690  32
#  3    3          1.732  13          3.606  23           4.796  33
#  4    4          2.000  14          3.742  24           4.899  34
#  5    5          2.236  15          3.873  25               5  35
#  6    6          2.449  16              4  26           5.099  36
#  7    7          2.646  17          4.123  27           5.196  37
#  8    8          2.828  18          4.243  28           5.292  38
#  9    9              3  19          4.359  29           5.385  39
#  10  10          3.162  20          4.472  30           5.477  40
#
#                  7   8               9
#  0   SquareRoot(√)  No  SquareRoot (√)
#  1           5.568  41           6.403
#  2           5.657  42           6.481
# ...

# %%
a = pd.read_html(r'https://www.vedantu.com/maths/square-root-table-from-1-to-50', header = None)

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 1

# %%
pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/BCF.csv")
# Out:
#            date  values.I2P  values.P2I  values.JPI
# 0    1996-04-01   -2.580556   -0.836444        63.3
# 1    1996-05-01   -2.882258   -1.972581        66.3
# 2    1996-06-01   -1.742778   -0.478778        59.7
# 3    1996-07-01   -0.397796   -1.574301        63.3
# 4    1996-08-01   -0.977151   -1.797312        63.8
# ..          ...         ...         ...         ...
# 112  2005-08-01   -2.144935   -1.646989        49.0
# 113  2005-09-01   -3.543270   -1.769889        49.9
# 114  2005-10-01   -4.500484   -2.309946        50.6
# 115  2005-11-01   -4.098556   -1.528611        57.4
# 116  2005-12-01   -5.797043   -2.872849        52.9
#
# [117 rows x 4 columns]

# %%
pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')        
#json is the dictionaries with combination of key value pair
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
js['user'][0]
# Out:
# {'login': 'jrbourbeau',
#  'id': 11656932,
#  'node_id': 'MDQ6VXNlcjExNjU2OTMy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/11656932?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jrbourbeau',
#  'html_url': 'https://github.com/jrbourbeau',
#  'followers_url': 'https://api.github.com/users/jrbourbeau/followers',
#  'following_url': 'https://api.github.com/users/jrbourbeau/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jrbourbeau/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jrbourbeau/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jrbourbeau/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jrbourbeau/orgs',
#  'repos_url': 'https://api.github.com/users/jrbourbeau/repos',
#  'events_url': 'https://api.github.com/users/jrbourbeau/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jrbourbeau/received_events',
#  'type': 'User',
# ...

# %%
js['user']     #key value pair data created, records from user coloumn
# Out:
# 0     {'login': 'jrbourbeau', 'id': 11656932, 'node_...
# 1     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 2     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 3     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 4     {'login': 'meeseeksmachine', 'id': 39504233, '...
# 5     {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 6     {'login': 'Pro-Coder04', 'id': 112387629, 'nod...
# 7     {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 8     {'login': 'bbassett-tibco', 'id': 81381063, 'n...
# 9     {'login': 'MichalRIcar', 'id': 62614119, 'node...
# 10    {'login': 'JMBurley', 'id': 23153616, 'node_id...
# 11    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 12    {'login': 'lohraspco', 'id': 25494629, 'node_i...
# 13    {'login': 'JMante1', 'id': 40006518, 'node_id'...
# 14    {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 15    {'login': 'SamRWest', 'id': 25496992, 'node_id...
# 16    {'login': 'JMBurley', 'id': 23153616, 'node_id...
# ...

# %%
pd.read_excel(r'C:\Users\rekha\Desktop\iNeuron\Attribute DataSet.xlsx')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.to_json('test253.json')

# %%
pwd  #present working directory
# Out:
# 'C:\\Users\\rekha'

# %%
df
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df.to_csv("C://test1.csv")  #permission error,nothing else, means open the anaconda prompt in admin mode not in user mode.
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:385, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     384 try:
# --> 385     file_obj = fsspec.open(
#     386         filepath_or_buffer, mode=fsspec_mode, **(storage_options or {})
#     387     ).open()
#     388 # GH 34626 Reads from Public Buckets without Credentials needs anon=True
#
# File ~\anaconda3\lib\site-packages\fsspec\core.py:140, in OpenFile.open(self)
#     133 """Materialise this as a real open file without context
#     134
#     135 The file should be explicitly closed to avoid enclosed file
#    (...)
#     138 been deleted; but a with-context is better style.
#     139 """
# --> 140 out = self.__enter__()
#     141 closer = out.close
#
# ...
