# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/rekha/Desktop/iNeuron/sales_data_final.csv' )

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Dra        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df["ship_mode"]
# Out:
# 0        Standard Class
# 1        Standard Class
# 2          Second Class
# 3          Second Class
# 4        Standard Class
#               ...
# 51285    Standard Class
# 51286    Standard Class
# 51287      Second Class
# 51288    Standard Class
# 51289    Standard Class
# Name: ship_mode, Length: 51290, dtype: object

# %%
type(df["ship_mode"])         #type of particulae column     series means
# Out:
# pandas.core.series.Series

# %%
df.dtypes                        #type of every column, object means string
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df[['profit','region']]      #two columns at a tyme enclosed it within a list
# Out:
#          profit   region
# 0      106.1400   Africa
# 1       36.0360  Oceania
# 2       29.6400     EMEA
# 3      -26.0550    North
# 4       37.7700  Oceania
# ...         ...      ...
# 51285    4.5188     West
# 51286    0.4200   Africa
# 51287   12.3600  Central
# 51288    0.5600    North
# 51289   -0.6048     West
#
# [51290 rows x 2 columns]

# %%
df["ship_mode"]          #without enclosing withing thr list
# Out:
# 0        Standard Class
# 1        Standard Class
# 2          Second Class
# 3          Second Class
# 4        Standard Class
#               ...
# 51285    Standard Class
# 51286    Standard Class
# 51287      Second Class
# 51288    Standard Class
# 51289    Standard Class
# Name: ship_mode, Length: 51290, dtype: object

# %%
df[['ship_mode']]
# Out:
#             ship_mode
# 0      Standard Class
# 1      Standard Class
# 2        Second Class
# 3        Second Class
# 4      Standard Class
# ...               ...
# 51285  Standard Class
# 51286  Standard Class
# 51287    Second Class
# 51288  Standard Class
# 51289  Standard Class
#
# [51290 rows x 1 columns]

# %%
type(df[['ship_mode']])          #data type with list is dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['ship_mode'])                #data type without list is series
# Out:
# pandas.core.series.Series

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.dtypes == 'object'              #only those column whose datatype is object
# Out:
# order_id           True
# order_date         True
# ship_date          True
# ship_mode          True
# customer_name      True
# segment            True
# state              True
# country            True
# market             True
# region             True
# product_id         True
# category           True
# sub_category       True
# product_name       True
# sales              True
# quantity          False
# discount          False
# profit            False
# shipping_cost     False
# order_priority     True
# year              False
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']      #perticular data type as object of the column
# Out:
# order_id          object
# order_date        object
# ship_date         object
# ship_mode         object
# customer_name     object
# segment           object
# state             object
# country           object
# market            object
# region            object
# product_id        object
# category          object
# sub_category      object
# product_name      object
# sales             object
# order_priority    object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index      #all the column records having object as datatype in list form
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'order_priority'],
#       dtype='object')

# %%
type(df.dtypes[df.dtypes == 'object'].index)
# Out:
# pandas.core.indexes.base.Index

# %%
df[df.dtypes[df.dtypes == 'object'].index]   #find dataframe
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
[df[df.dtypes[df.dtypes == 'object'].index].describe()]   #Description of perticular column
# Out:
# [              order_id order_date   ship_date       ship_mode  \
#  count            51290      51290       51290           51290
#  unique           25035       1430        1464               4
#  top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
#  freq                14        135         130           30775
#
#            customer_name   segment       state        country market   region  \
#  count             51290     51290       51290          51290  51290    51290
#  unique              795         3        1094            147      7       13
#  top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
#  freq                108     26518        2001           9994  11002    11117
#
#               product_id         category sub_category product_name  sales  \
#  count             51290            51290        51290        51290  51290
#  unique            10292                3           17         3788   2246
# ...

# %%
df[(df['shipping_cost']>100) & (df['profit']<10)]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# 625      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# ...                ...         ...         ...             ...
# 50781   CA-2014-147956  12/25/2014    1/1/2015  Standard Class
# 50969   US-2014-120166  12/27/2014  12/31/2014  Standard Class
# 50970  ES-2014-4296634  12/27/2014    1/2/2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014    1/1/2015    Second Class
#
#               customer_name    segment                         state  \
# 8              Ken Lonsdale   Consumer                      Auckland
# ...

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df[['profit','customer_name']].max()
# Out:
# profit                     8399.976
# customer_name    Zuschuss Donatelli
# dtype: object

# %%
df[['profit','customer_name']].min()
# Out:
# profit               -6599.978
# customer_name    Aaron Bergman
# dtype: object

# %%
df['order_date']
# Out:
# 0          1/1/2011
# 1          1/1/2011
# 2          1/1/2011
# 3          1/1/2011
# 4          1/1/2011
#             ...
# 51285    12/31/2014
# 51286    12/31/2014
# 51287    12/31/2014
# 51288    12/31/2014
# 51289    12/31/2014
# Name: order_date, Length: 51290, dtype: object

# %%
date = pd.to_datetime(df['order_date'])

# %%
date
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['converted_order_date'] = pd.to_datetime(df['order_date'])

# %%
df.head()                #last column has inserted as converted_order_date
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#   shipping_cost order_priority converted_order_date converted_order_year  \
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sales  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...   408
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   120
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...    66
# 3  Home Office        Stockholm     Sweden      EU    North  ...    45
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   114
#
#   quantity discount   profit shipping_cost  order_priority  year  \
# ...

# %%
df['order_date_year'] = pd.to_datetime(df['order_date']).dt.year               #add column for year

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#   shipping_cost order_priority converted_order_date converted_order_year  \
# ...

# %%
df['order_date_month'] = pd.to_datetime(df['order_date']).dt.month        #add column for month

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#   shipping_cost order_priority converted_order_date converted_order_year  \
# ...

# %%
df['order_date_week'] = pd.to_datetime(df['order_date']).dt.week        #add column for week
# Out:
# C:\Users\rekha\AppData\Local\Temp\ipykernel_33516\1311132948.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['order_date_week'] = pd.to_datetime(df['order_date']).dt.week

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#   shipping_cost order_priority converted_order_date converted_order_year  \
# ...

# %%
df[['order_date_year', 'order_date_week']]           #extract two columns only
# Out:
#        order_date_year  order_date_week
# 0                 2011               52
# 1                 2011               52
# 2                 2011               52
# 3                 2011               52
# 4                 2011               52
# ...                ...              ...
# 51285             2014                1
# 51286             2014                1
# 51287             2014                1
# 51288             2014                1
# 51289             2014                1
#
# [51290 rows x 2 columns]

# %%
df[df['order_date_year'] == 2014]                       # extract the data from yr 2014 only
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 33759  ES-2014-2774938    1/1/2014  1/3/2014    Second Class
# 33760    IN-2014-47134    1/1/2014  1/5/2014  Standard Class
# 33761  IT-2014-4810734    1/1/2014  1/3/2014    Second Class
# 33762   US-2014-105830    1/1/2014  1/3/2014     First Class
# 33763   CA-2014-160395    1/1/2014  1/7/2014  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 33759       Fred Harton   Consumer     Ile-de-France         France      EU
# 33760       Kean Nguyen  Corporate          Victoria      Australia    APAC
# ...

# %%
df['order_date_month'].value_counts()       #sells counts on basis of months i.e. highest to lowest
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: order_date_month, dtype: int64

# %%
df['cost_to_company']= df['discount'] + df['shipping_cost']                   #what will be the cost for company

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#   shipping_cost order_priority converted_order_date converted_order_year  \
# ...

# %%
df['cost_to_company'].max()         #maximum cost to company
# Out:
# 933.57

# %%
df[df['cost_to_company']== max(df['cost_to_company'])]['product_name']     #product name for max cost
# Out:
# 13891    Plantronics CS510 - Over-the-Head monaural Wir...
# Name: product_name, dtype: object

# %%
df[df['cost_to_company']== min(df['cost_to_company'])]['product_name']      #product for which min cost to company
# Out:
# 9827                     Acco Index Tab, Economy
# 11846    Eaton Computer Printout Paper, 8.5 x 11
# Name: product_name, dtype: object

# %%
df[df['cost_to_company']== min(df['cost_to_company'])]
# Out:
#              order_id order_date  ship_date       ship_mode  customer_name  \
# 9827   MX-2012-140767  2/18/2012  2/22/2012  Standard Class     Ross Baird
# 11846  MX-2012-134460  5/22/2012  5/26/2012    Second Class  Mick Crebagga
#
#            segment      state    country market   region  ...  year  \
# 9827   Home Office  S?o Paulo     Brazil  LATAM    South  ...  2012
# 11846     Consumer    Managua  Nicaragua  LATAM  Central  ...  2012
#
#       converted_order_date      Rekha converted_order_year  \
# 9827            2012-02-18 2012-02-18                 2012
# 11846           2012-05-22 2012-05-22                 2012
#
#       converted_order_month  converted_order_week  order_date_year  \
# 9827                      2                     7             2012
# 11846                     5                    21             2012
#
#        order_date_month  order_date_week cost_to_company
# 9827                  2                7             0.0
# ...

# %%
df[df['cost_to_company']== max(df['cost_to_company'])]
# Out:
#              order_id order_date  ship_date ship_mode customer_name   segment  \
# 13891  CA-2012-124891  7/31/2012  7/31/2012  Same Day   Rick Hansen  Consumer
#
#           state        country market region  ...  year converted_order_date  \
# 13891  New York  United States     US   East  ...  2012           2012-07-31
#
#            Rekha converted_order_year converted_order_month  \
# 13891 2012-07-31                 2012                     7
#
#        converted_order_week  order_date_year  order_date_month  \
# 13891                    31             2012                 7
#
#        order_date_week cost_to_company
# 13891               31          933.57
#
# [1 rows x 30 columns]

# %%
df.drop('cost_to_company', axis = 1)          # to drop the column temporary from df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()                   #deleted column will remains in original df as it is
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  year  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...  2011
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...  2011
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...  2011
# 3  Home Office        Stockholm     Sweden      EU    North  ...  2011
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...  2011
#
#   converted_order_date      Rekha converted_order_year converted_order_month  \
# ...

# %%
df.drop('Rekha', axis = 1)          #deleted the column Rekha
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df = df.drop('Rekha', axis = 1)   #to delete permanantly assign the value to original df

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#   order_priority  year converted_order_date converted_order_year  \
# 0         Medium  2011           2011-01-01                 2011
# ...

# %% [markdown]
# # OR

# %%
df.drop('year', axis = 1, inplace=True)            #delete permanantly column 'Year'

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#   shipping_cost order_priority converted_order_date converted_order_year  \
# ...

# %%
df.drop(1)             #to drop the 1st row
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()          #row not deleted permanantly
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#   shipping_cost order_priority converted_order_date converted_order_year  \
# ...

# %%
df.drop(1, inplace = True)

# %%
df.head()               #Row 1 has deleted permanantly
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 5    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 5     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#   shipping_cost order_priority converted_order_date converted_order_year  \
# ...

# %%
df.loc[[2,3]]                     #To filter out record row vise.
# Out:
#           order_id order_date ship_date     ship_mode  customer_name  \
# 2     HU-2011-1220   1/1/2011  1/5/2011  Second Class  Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011  Second Class   Eugene Moren
#
#        segment      state  country market region  ... shipping_cost  \
# 2     Consumer   Budapest  Hungary   EMEA   EMEA  ...          8.17
# 3  Home Office  Stockholm   Sweden     EU  North  ...          4.82
#
#   order_priority converted_order_date converted_order_year  \
# 2           High           2011-01-01                 2011
# 3           High           2011-01-01                 2011
#
#   converted_order_month  converted_order_week  order_date_year  \
# 2                     1                    52             2011
# 3                     1                    52             2011
#
#    order_date_month  order_date_week cost_to_company
# 2                 1               52            8.17
# 3                 1               52            5.32
#
# ...

# %%
df.loc[2:6]               #Filter out row record fro 2 to 6
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 5    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 6     CA-2011-1510   1/2/2011  1/6/2011  Standard Class  Magdelene Morse
#
#        segment            state    country  market   region  ...  \
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 5     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 6     Consumer          Ontario     Canada  Canada   Canada  ...
#
#   shipping_cost order_priority converted_order_date converted_order_year  \
# ...

# %%
df.loc[2:6:2]             #Filter out row record fro 2 to 6 jumping of 2
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 2   HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 4  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 6   CA-2011-1510   1/2/2011  1/6/2011  Standard Class  Magdelene Morse
#
#     segment            state    country  market   region  ... shipping_cost  \
# 2  Consumer         Budapest    Hungary    EMEA     EMEA  ...          8.17
# 4  Consumer  New South Wales  Australia    APAC  Oceania  ...          4.70
# 6  Consumer          Ontario     Canada  Canada   Canada  ...         24.10
#
#   order_priority converted_order_date converted_order_year  \
# 2           High           2011-01-01                 2011
# 4         Medium           2011-01-01                 2011
# 6         Medium           2011-01-02                 2011
#
#   converted_order_month  converted_order_week  order_date_year  \
# 2                     1                    52             2011
# ...

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.loc[2:5, ['order_date', 'ship_date', 'ship_mode', 'customer_name']]       #to find perticular date from df
# Out:
#   order_date ship_date       ship_mode  customer_name
# 2   1/1/2011  1/5/2011    Second Class  Annie Thurman
# 3   1/1/2011  1/5/2011    Second Class   Eugene Moren
# 4   1/1/2011  1/8/2011  Standard Class    Joseph Holt
# 5   1/1/2011  1/8/2011  Standard Class    Joseph Holt

# %% [markdown]
# # OR

# %%
df.iloc[1:5, 1:5]                     #iloc is recignise default indexes
# Out:
#   order_date ship_date       ship_mode  customer_name
# 2   1/1/2011  1/5/2011    Second Class  Annie Thurman
# 3   1/1/2011  1/5/2011    Second Class   Eugene Moren
# 4   1/1/2011  1/8/2011  Standard Class    Joseph Holt
# 5   1/1/2011  1/8/2011  Standard Class    Joseph Holt

# %%
df.loc[2:20:3, ['order_date', 'ship_date', 'ship_mode', 'customer_name']]       #to find perticular date from df
# Out:
#    order_date ship_date       ship_mode  customer_name
# 2    1/1/2011  1/5/2011    Second Class  Annie Thurman
# 5    1/1/2011  1/8/2011  Standard Class    Joseph Holt
# 8    1/3/2011  1/9/2011  Standard Class   Ken Lonsdale
# 11   1/3/2011  1/7/2011    Second Class   Larry Blacks
# 14   1/3/2011  1/9/2011  Standard Class   Ken Lonsdale
# 17   1/3/2011  1/9/2011  Standard Class   Ken Lonsdale
# 20   1/3/2011  1/3/2011        Same Day    Kean Nguyen

# %%
df.iloc[0:3, 0:4]
# Out:
#           order_id order_date ship_date       ship_mode
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class

# %%
df.iloc[1:5, 3:6]
# Out:
#         ship_mode  customer_name      segment
# 2    Second Class  Annie Thurman     Consumer
# 3    Second Class   Eugene Moren  Home Office
# 4  Standard Class    Joseph Holt     Consumer
# 5  Standard Class    Joseph Holt     Consumer

# %%
df.dtypes                      #datatype of all columns
# Out:
# order_id                         object
# order_date                       object
# ship_date                        object
# ship_mode                        object
# customer_name                    object
# segment                          object
# state                            object
# country                          object
# market                           object
# region                           object
# product_id                       object
# category                         object
# sub_category                     object
# product_name                     object
# sales                            object
# quantity                          int64
# discount                        float64
# profit                          float64
# shipping_cost                   float64
# order_priority                   object
# converted_order_date     datetime64[ns]
# converted_order_year              int64
# converted_order_month             int64
# ...

# %%
df.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')]             #columns having perticular datatypes
# Out:
# quantity                   int64
# discount                 float64
# profit                   float64
# shipping_cost            float64
# converted_order_year       int64
# converted_order_month      int64
# converted_order_week       int64
# order_date_year            int64
# order_date_month           int64
# order_date_week            int64
# cost_to_company          float64
# dtype: object

# %%
df.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')].index
# Out:
# Index(['quantity', 'discount', 'profit', 'shipping_cost',
#        'converted_order_year', 'converted_order_month', 'converted_order_week',
#        'order_date_year', 'order_date_month', 'order_date_week',
#        'cost_to_company'],
#       dtype='object')

# %%
df2=df[df.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')].index ]

# %%
df2
# Out:
#        quantity  discount    profit  shipping_cost  converted_order_year  \
# 0             2       0.0  106.1400          35.46                  2011
# 2             4       0.0   29.6400           8.17                  2011
# 3             3       0.5  -26.0550           4.82                  2011
# 4             5       0.1   37.7700           4.70                  2011
# 5             2       0.1   15.3420           1.80                  2011
# ...         ...       ...       ...            ...                   ...
# 51285         2       0.2    4.5188           0.89                  2014
# 51286         1       0.0    0.4200           0.49                  2014
# 51287         3       0.0   12.3600           0.35                  2014
# 51288         1       0.0    0.5600           0.20                  2014
# 51289         3       0.2   -0.6048           0.17                  2014
#
#        converted_order_month  converted_order_week  order_date_year  \
# ...

# %%
df2[df2 >100]                 #value is greatr than 100
# Out:
#        quantity  discount  profit  shipping_cost  converted_order_year  \
# 0           NaN       NaN  106.14            NaN                  2011
# 2           NaN       NaN     NaN            NaN                  2011
# 3           NaN       NaN     NaN            NaN                  2011
# 4           NaN       NaN     NaN            NaN                  2011
# 5           NaN       NaN     NaN            NaN                  2011
# ...         ...       ...     ...            ...                   ...
# 51285       NaN       NaN     NaN            NaN                  2014
# 51286       NaN       NaN     NaN            NaN                  2014
# 51287       NaN       NaN     NaN            NaN                  2014
# 51288       NaN       NaN     NaN            NaN                  2014
# 51289       NaN       NaN     NaN            NaN                  2014
#
#        converted_order_month  converted_order_week  order_date_year  \
# ...

# %%
df3 = df2[df2 >100]

# %%
df3
# Out:
#        quantity  discount  profit  shipping_cost  converted_order_year  \
# 0           NaN       NaN  106.14            NaN                  2011
# 2           NaN       NaN     NaN            NaN                  2011
# 3           NaN       NaN     NaN            NaN                  2011
# 4           NaN       NaN     NaN            NaN                  2011
# 5           NaN       NaN     NaN            NaN                  2011
# ...         ...       ...     ...            ...                   ...
# 51285       NaN       NaN     NaN            NaN                  2014
# 51286       NaN       NaN     NaN            NaN                  2014
# 51287       NaN       NaN     NaN            NaN                  2014
# 51288       NaN       NaN     NaN            NaN                  2014
# 51289       NaN       NaN     NaN            NaN                  2014
#
#        converted_order_month  converted_order_week  order_date_year  \
# ...

# %%
df3.dropna()                    #drop all rows where doesnt have a single value of NA
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, converted_order_year, converted_order_month, converted_order_week, order_date_year, order_date_month, order_date_week, cost_to_company]
# Index: []

# %%
df3.dropna(axis = 1)              #drop all columns where doesnt have a single value of NA
# Out:
#        converted_order_year  order_date_year
# 0                      2011             2011
# 2                      2011             2011
# 3                      2011             2011
# 4                      2011             2011
# 5                      2011             2011
# ...                     ...              ...
# 51285                  2014             2014
# 51286                  2014             2014
# 51287                  2014             2014
# 51288                  2014             2014
# 51289                  2014             2014
#
# [51289 rows x 2 columns]

# %%
df3.dropna(thresh=5)                      #drop the rows where na value is 5
# Out:
#        quantity  discount    profit  shipping_cost  converted_order_year  \
# 7           NaN       NaN  110.4120         125.32                  2011
# 27          NaN       NaN  609.8400         109.13                  2011
# 43          NaN       NaN  999.3600         191.20                  2011
# 58          NaN       NaN  746.4078         258.99                  2011
# 84          NaN       NaN  260.8200         275.52                  2011
# ...         ...       ...       ...            ...                   ...
# 51149       NaN       NaN  899.1000         236.49                  2014
# 51150       NaN       NaN  317.1600         184.60                  2014
# 51151       NaN       NaN  768.8800         155.85                  2014
# 51152       NaN       NaN  314.0384         139.47                  2014
# 51228       NaN       NaN  301.4660         253.25                  2014
#
#        converted_order_month  converted_order_week  order_date_year  \
# ...

# %%
df3.fillna(value='REKHA')               #Na is replaced by the value we want
# Out:
#       quantity discount  profit shipping_cost  converted_order_year  \
# 0        REKHA    REKHA  106.14         REKHA                  2011
# 2        REKHA    REKHA   REKHA         REKHA                  2011
# 3        REKHA    REKHA   REKHA         REKHA                  2011
# 4        REKHA    REKHA   REKHA         REKHA                  2011
# 5        REKHA    REKHA   REKHA         REKHA                  2011
# ...        ...      ...     ...           ...                   ...
# 51285    REKHA    REKHA   REKHA         REKHA                  2014
# 51286    REKHA    REKHA   REKHA         REKHA                  2014
# 51287    REKHA    REKHA   REKHA         REKHA                  2014
# 51288    REKHA    REKHA   REKHA         REKHA                  2014
# 51289    REKHA    REKHA   REKHA         REKHA                  2014
#
#       converted_order_month converted_order_week  order_date_year  \
# 0                     REKHA                REKHA             2011
# ...

# %%
df.groupby('order_date_year')['discount'].mean()
# Out:
# order_date_year
# 2011    0.148193
# 2012    0.141286
# 2013    0.140265
# 2014    0.143291
# Name: discount, dtype: float64

# %%
df.groupby('order_date_year')['profit'].mean()
# Out:
# order_date_year
# 2011    27.665308
# 2012    28.043722
# 2013    29.604519
# 2014    28.758540
# Name: profit, dtype: float64

# %%
df.dtypes
# Out:
# order_id                         object
# order_date                       object
# ship_date                        object
# ship_mode                        object
# customer_name                    object
# segment                          object
# state                            object
# country                          object
# market                           object
# region                           object
# product_id                       object
# category                         object
# sub_category                     object
# product_name                     object
# sales                            object
# quantity                          int64
# discount                        float64
# profit                          float64
# shipping_cost                   float64
# order_priority                   object
# converted_order_date     datetime64[ns]
# converted_order_year              int64
# converted_order_month             int64
# ...

# %%
df.sales
# Out:
# 0        408
# 2         66
# 3         45
# 4        114
# 5         55
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51289, dtype: object

# %%
df['sales'] = df.sales.str.replace(',', "").astype(int)                 #sales columns is converted from object to int

# %%
df.dtypes
# Out:
# order_id                         object
# order_date                       object
# ship_date                        object
# ship_mode                        object
# customer_name                    object
# segment                          object
# state                            object
# country                          object
# market                           object
# region                           object
# product_id                       object
# category                         object
# sub_category                     object
# product_name                     object
# sales                             int32
# quantity                          int64
# discount                        float64
# profit                          float64
# shipping_cost                   float64
# order_priority                   object
# converted_order_date     datetime64[ns]
# converted_order_year              int64
# converted_order_month             int64
# ...

# %%
df.groupby('order_date_year')['sales'].mean()
# Out:
# order_date_year
# 2011    251.127153
# 2012    244.252235
# 2013    246.819335
# 2014    245.282129
# Name: sales, dtype: float64

# %%
df.groupby('order_date_year')['sales'].sum()
# Out:
# order_date_year
# 2011    2259391
# 2012    2677493
# 2013    3405860
# 2014    4300041
# Name: sales, dtype: int32

# %%
df.groupby('order_date_year')['sales'].sum()
# Out:
# order_date_year
# 2011    2259391
# 2012    2677493
# 2013    3405860
# 2014    4300041
# Name: sales, dtype: int32
